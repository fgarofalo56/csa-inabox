# %%
//Log Analytics query to view all Databricks Workspaces

DatabricksAccounts
# Out:
# Commands completed successfully.
# Total execution time: 00:00:00.037
# <table></table>

# %%
# Out:
# Commands completed successfully.
# Total execution time: 00:00:00.058
# <table></table>
