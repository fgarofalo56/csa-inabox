# %% [markdown]
# #### dbt Workbook
# ##### This workbook is used to show samples and examples of dbt functionality and features.
# ###### References:
# - https://docs.getdbt.com/docs/introduction
# - https://docs.getdbt.com/docs/core/installation
# - https://docs.getdbt.com/docs/core/pip-install

# %%
# Install via pip

# 1. Create a new virtual environment
python -m venv dbt-env

# 2. Activate the virtual environment
.\dbt-env\Scripts\Activate.ps1

# Exit virtual environment
deactivate

# %%
# Path: scripts/PowerShell/EnvironmentVariables.ps1
# Add directory to PATH environment variable

# New-Item -Path Env: -Name "dbt-env" -Value "S:\Repos\GitHub\csa-inabox\tools\dbt\dbt-env\Scripts"

# $env:PATH += ";%dbt-env%"

#update environment variable
Set-Item -Path Env:"dbt-env" -Value "S:\Repos\GitHub\csa-inabox\tools\dbt\dbt-env\Scripts"

#remove from PATH environment variable
$env:PATH = $env:PATH.Replace(";S:\Repos\GitHub\csa-inabox\tools\dbt\dbt-env\Scripts", ";%dbt-env%")

# %%
# How to call the script to Avtivate venv

& "$Env:dbt-env\Activate.ps1"
# Out:
# &:
# Line |
#    3 |  & "$Env:dbt-env\Activate.ps1"
#      |    ~~~~~~~~~~~~~~~~~~~~~~~~~~~
#      | The module '-env' could not be loaded. For more information, run 'Import-Module -env'.

# %%
pip install dbt

# %% [markdown]
# #### Install adapters and dependencies
# https://docs.getdbt.com/docs/core/connect-data-platform/about-core-connections
#
# https://docs.getdbt.com/reference/resource-configs/azuresynapse-configs
# Synapse DBT:  https://github.com/microsoft/dbt-synapse/
#
#
#
#
# - pip install dbt-spark
# - pip install dbt-databricks
# - pip install --pre dbt-synapse
#
# Synapse DBT:
# - https://docs.getdbt.com/docs/core/connect-data-platform/azuresynapse-setup
# - https://docs.getdbt.com/reference/resource-configs/azuresynapse-configs

# %%
.\dbt-env\Scripts\Activate.ps1

pip uninstall dbt-synapse
# Out:
# Found existing installation: dbt-synapse 1.4.0
# Uninstalling dbt-synapse-1.4.0:
#   Would remove:
#     s:\repos\github\csa-inabox\tools\dbt\dbt-env\lib\site-packages\dbt\*
#     s:\repos\github\csa-inabox\tools\dbt\dbt-env\lib\site-packages\dbt_synapse-1.4.0.dist-info\*
#   Would not remove (might be manually added):
#     s:\repos\github\csa-inabox\tools\dbt\dbt-env\lib\site-packages\dbt\adapters\base\__init__.py
#     s:\repos\github\csa-inabox\tools\dbt\dbt-env\lib\site-packages\dbt\adapters\base\column.py
#     s:\repos\github\csa-inabox\tools\dbt\dbt-env\lib\site-packages\dbt\adapters\base\connections.py
#     s:\repos\github\csa-inabox\tools\dbt\dbt-env\lib\site-packages\dbt\adapters\base\impl.py
#     s:\repos\github\csa-inabox\tools\dbt\dbt-env\lib\site-packages\dbt\adapters\base\meta.py
#     s:\repos\github\csa-inabox\tools\dbt\dbt-env\lib\site-packages\dbt\adapters\base\plugin.py
# ...

# %%
pip install dbt-core --upgrade
# Out:
# ...
#   Using cached mashumaro-3.8.1-py3-none-any.whl.metadata (97 kB)
# ...
#    ---------------------------------------- 995.1/995.1 kB 4.8 MB/s eta 0:00:00
# Using cached mashumaro-3.8.1-py3-none-any.whl (74 kB)
# ...
#   Attempting uninstall: mashumaro
#     Found existing installation: mashumaro 3.3.1
#     Uninstalling mashumaro-3.3.1:
#       Successfully uninstalled mashumaro-3.3.1
#   Attempting uninstall: dbt-core
#     Found existing installation: dbt-core 1.4.9
#     Uninstalling dbt-core-1.4.9:
#       Successfully uninstalled dbt-core-1.4.9
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dbt-sqlserver 1.4.3 requires dbt-core~=1.4.5, but you have dbt-core 1.6.6 which is incompatible.
# ...
